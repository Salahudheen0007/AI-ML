# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris
iris = load_iris()
X = iris['data']
y = iris['target']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Input

# %%
from tensorflow import keras
from keras import layers
from keras import regularizers

# %%
model = Sequential()
# this is a classification problem and output has 3 classes
model.add(Input(shape=(4,)))
model.add(Dense(10,activation='relu',kernel_regularizer=regularizers.L1L2(l1=1e-5,l2 = 1e-4)))
model.add(Dense(20,activation='relu',kernel_regularizer=regularizers.L1L2(l1=1e-5,l2 = 1e-4)))
model.add(Dense(3,activation='softmax',activity_regularizer=regularizers.L2(1e-5)))

# %%
#without regularization
model1 = Sequential()
# this is a classification problem and output has 3 classes
model1.add(Input(shape=(4,)))
model1.add(Dense(10,activation='relu'))
model1.add(Dense(20,activation='relu'))
model1.add(Dense(3,activation='softmax'))

# %%
from tensorflow.keras.optimizers import Adam
adam_opt  = Adam(learning_rate = LEARNING_RATE,beta_1 = 0.9,beta_2 = 0.999,epsilon = 1e-8)
model1.compile(optimizer=adam_opt,loss = 'sparse_categorical_crossentropy',metrics = ['accuracy'])

# %%
history1 = model1.fit(X_train,y_train,
                    epochs = 20,
                    validation_data = (X_test,y_test),
                    batch_size = 32)
# Out:
# Epoch 1/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 144ms/step - accuracy: 0.4732 - loss: 1.1887 - val_accuracy: 0.7105 - val_loss: 0.8334
# Epoch 2/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6786 - loss: 0.8586 - val_accuracy: 0.7368 - val_loss: 0.7668
# Epoch 3/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6964 - loss: 0.7700 - val_accuracy: 0.7368 - val_loss: 0.6959
# Epoch 4/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8125 - loss: 0.6908 - val_accuracy: 1.0000 - val_loss: 0.5809
# Epoch 5/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9286 - loss: 0.5975 - val_accuracy: 0.9474 - val_loss: 0.4921
# Epoch 6/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9643 - loss: 0.5246 - val_accuracy: 0.8421 - val_loss: 0.4282
# Epoch 7/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7946 - loss: 0.4668 - val_accuracy: 0.8158 - val_loss: 0.3826
# Epoch 8/20
# ...

# %%
LEARNING_RATE = 0.01

# %%
from tensorflow.keras.optimizers import Adam
adam_opt  = Adam(learning_rate = LEARNING_RATE,beta_1 = 0.9,beta_2 = 0.999,epsilon = 1e-8)
model.compile(optimizer=adam_opt,loss = 'sparse_categorical_crossentropy',metrics = ['accuracy'])

# %%
history = model.fit(X_train,y_train,
                    epochs = 20,
                    validation_data = (X_test,y_test),
                    batch_size = 32)
# Out:
# Epoch 1/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.4464 - loss: 1.1804 - val_accuracy: 0.4737 - val_loss: 1.0361
# Epoch 2/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4018 - loss: 0.9619 - val_accuracy: 0.3947 - val_loss: 0.8258
# Epoch 3/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7232 - loss: 0.7649 - val_accuracy: 0.8684 - val_loss: 0.6505
# Epoch 4/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9375 - loss: 0.6366 - val_accuracy: 0.8684 - val_loss: 0.4954
# Epoch 5/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8214 - loss: 0.5256 - val_accuracy: 0.8684 - val_loss: 0.4163
# Epoch 6/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9018 - loss: 0.4344 - val_accuracy: 0.8684 - val_loss: 0.3781
# Epoch 7/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9464 - loss: 0.4012 - val_accuracy: 0.8947 - val_loss: 0.3312
# Epoch 8/20
# ...

# %%
plt.plot(history.history['val_loss'],label = "testing loss of regularized")
plt.plot(history1.history["val_loss"],label = "testing loss of normal")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
from tensorflow.keras.layers import Dropout
model2 = Sequential()
# this is a classification problem and output has 3 classes
model2.add(Input(shape=(4,)))
model2.add(Dense(10,activation='relu'))
model2.add(Dropout(0.3))
model2.add(Dense(20,activation='relu'))
model2.add(Dense(3,activation='softmax'))

# %%
model2.compile(optimizer=adam_opt,loss = 'sparse_categorical_crossentropy',metrics = ['accuracy'])
history2 = model2.fit(X_train,y_train,
                    epochs = 20,
                    validation_data = (X_test,y_test))
# Out:
# Epoch 1/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - accuracy: 0.3125 - loss: 1.3665 - val_accuracy: 0.3421 - val_loss: 0.9564
# Epoch 2/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4196 - loss: 1.1540 - val_accuracy: 0.3947 - val_loss: 0.9029
# Epoch 3/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.3929 - loss: 1.0608 - val_accuracy: 0.7105 - val_loss: 0.8107
# Epoch 4/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.4375 - loss: 0.9683 - val_accuracy: 0.8947 - val_loss: 0.7407
# Epoch 5/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.3750 - loss: 1.0634 - val_accuracy: 0.7368 - val_loss: 0.7523
# Epoch 6/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4464 - loss: 0.9827 - val_accuracy: 0.8158 - val_loss: 0.7898
# Epoch 7/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5625 - loss: 0.8672 - val_accuracy: 0.7105 - val_loss: 0.7831
# Epoch 8/20
# ...

# %%
plt.plot(history.history['val_loss'],label = "testing loss of regularized")
plt.plot(history1.history["val_loss"],label = "testing loss of normal")
plt.plot(history2.history["val_loss"],label = "testing loss of dropout")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend()
plt.show()
