# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
sent = [
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'I am a good boy',
    'I am a good developer',
    'understand the meaning of words',
    'your videos are good'
]

# %%
tokenizer = Tokenizer(num_words=10000,oov_token='<OOv>')
tokenizer.fit_on_texts(sent)

# %%
sequences = tokenizer.texts_to_sequences(sent)
print("word index",tokenizer.word_index)
print("sequences",sequences)
# Out:
# word index {'<OOv>': 1, 'the': 2, 'of': 3, 'good': 4, 'glass': 5, 'i': 6, 'am': 7, 'a': 8, 'milk': 9, 'juice': 10, 'cup': 11, 'tea': 12, 'boy': 13, 'developer': 14, 'understand': 15, 'meaning': 16, 'words': 17, 'your': 18, 'videos': 19, 'are': 20}
# sequences [[2, 5, 3, 9], [2, 5, 3, 10], [2, 11, 3, 12], [6, 7, 8, 4, 13], [6, 7, 8, 4, 14], [15, 2, 16, 3, 17], [18, 19, 20, 4]]

# %%
#  Padding
from tensorflow.keras.preprocessing.sequence import pad_sequences
sent_length = 8
embedded_docs = pad_sequences(sequences,maxlen = sent_length,padding = 'pre')
print("after padding: \n",embedded_docs)
# Out:
# after padding:
#  [[ 0  0  0  0  2  5  3  9]
#  [ 0  0  0  0  2  5  3 10]
#  [ 0  0  0  0  2 11  3 12]
#  [ 0  0  0  6  7  8  4 13]
#  [ 0  0  0  6  7  8  4 14]
#  [ 0  0  0 15  2 16  3 17]
#  [ 0  0  0  0 18 19 20  4]]

# %%
# Embedding layer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding
model = Sequential()
model.add(Embedding(input_dim = 10000,output_dim = 10,input_length = sent_length))
model.compile(optimizer = 'adam',loss = 'mse')
# Out:
# c:\AI_ML_fresh\.venv\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
embeddings = model.predict(embedded_docs)
print("Embedding for all sentences:\n", embeddings)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Embedding for all sentences:
#  [[[-0.01638477 -0.03495693 -0.04868267 -0.03953408 -0.02252248
#     0.02061552  0.00963671  0.03350308 -0.01113061  0.04103405]
#   [-0.01638477 -0.03495693 -0.04868267 -0.03953408 -0.02252248
#     0.02061552  0.00963671  0.03350308 -0.01113061  0.04103405]
#   [-0.01638477 -0.03495693 -0.04868267 -0.03953408 -0.02252248
#     0.02061552  0.00963671  0.03350308 -0.01113061  0.04103405]
#   [-0.01638477 -0.03495693 -0.04868267 -0.03953408 -0.02252248
#     0.02061552  0.00963671  0.03350308 -0.01113061  0.04103405]
#   [ 0.0451568  -0.01530717  0.02476313  0.01694189 -0.02909672
#     0.00123024 -0.02663044 -0.00308689 -0.01980902  0.02268827]
#   [ 0.03651438 -0.00565831 -0.02682968 -0.03454692  0.00796914
#    -0.03845124  0.00583944  0.04910171 -0.01597941  0.03519932]
#   [-0.00675353  0.02575165  0.01682762  0.00756405  0.04100749
#    -0.04509603 -0.01723411 -0.02062552  0.01032336  0.01226914]
#   [-0.04161846  0.00954301 -0.02810344 -0.01268836  0.01530553
#    -0.04013573  0.04629035 -0.02158129  0.01262447  0.04261962]]
#
#  [[-0.01638477 -0.03495693 -0.04868267 -0.03953408 -0.02252248
#     0.02061552  0.00963671  0.03350308 -0.01113061  0.04103405]
#   [-0.01638477 -0.03495693 -0.04868267 -0.03953408 -0.02252248
#     0.02061552  0.00963671  0.03350308 -0.01113061  0.04103405]
#   [-0.01638477 -0.03495693 -0.04868267 -0.03953408 -0.02252248
#     0.02061552  0.00963671  0.03350308 -0.01113061  0.04103405]
#   [-0.01638477 -0.03495693 -0.04868267 -0.03953408 -0.02252248
#     0.02061552  0.00963671  0.03350308 -0.01113061  0.04103405]
#   [ 0.0451568  -0.01530717  0.02476313  0.01694189 -0.02909672
#     0.00123024 -0.02663044 -0.00308689 -0.01980902  0.02268827]
#   [ 0.03651438 -0.00565831 -0.02682968 -0.03454692  0.00796914
#    -0.03845124  0.00583944  0.04910171 -0.01597941  0.03519932]
#   [-0.00675353  0.02575165  0.01682762  0.00756405  0.04100749
#    -0.04509603 -0.01723411 -0.02062552  0.01032336  0.01226914]
#   [ 0.04631009 -0.03778397  0.00549371 -0.03773115 -0.02532437
#     0.03680042  0.02039747  0.02826418  0.0061501   0.03196955]]
#
#  [[-0.01638477 -0.03495693 -0.04868267 -0.03953408 -0.02252248
#     0.02061552  0.00963671  0.03350308 -0.01113061  0.04103405]
#   [-0.01638477 -0.03495693 -0.04868267 -0.03953408 -0.02252248
#     0.02061552  0.00963671  0.03350308 -0.01113061  0.04103405]
#   [-0.01638477 -0.03495693 -0.04868267 -0.03953408 -0.02252248
#     0.02061552  0.00963671  0.03350308 -0.01113061  0.04103405]
#   [-0.01638477 -0.03495693 -0.04868267 -0.03953408 -0.02252248
#     0.02061552  0.00963671  0.03350308 -0.01113061  0.04103405]
#   [ 0.0451568  -0.01530717  0.02476313  0.01694189 -0.02909672
#     0.00123024 -0.02663044 -0.00308689 -0.01980902  0.02268827]
#   [-0.01422006 -0.03204548  0.044693    0.00841528 -0.03510417
#     0.00581061 -0.02542799 -0.00870537 -0.01491264 -0.04180845]
#   [-0.00675353  0.02575165  0.01682762  0.00756405  0.04100749
#    -0.04509603 -0.01723411 -0.02062552  0.01032336  0.01226914]
#   [-0.01636515  0.03720265  0.04933859 -0.02183514 -0.02268328
#     0.03760325 -0.01227429  0.03954322  0.03943468 -0.01232141]]
#
#  [[-0.01638477 -0.03495693 -0.04868267 -0.03953408 -0.02252248
#     0.02061552  0.00963671  0.03350308 -0.01113061  0.04103405]
#   [-0.01638477 -0.03495693 -0.04868267 -0.03953408 -0.02252248
#     0.02061552  0.00963671  0.03350308 -0.01113061  0.04103405]
#   [-0.01638477 -0.03495693 -0.04868267 -0.03953408 -0.02252248
#     0.02061552  0.00963671  0.03350308 -0.01113061  0.04103405]
#   [ 0