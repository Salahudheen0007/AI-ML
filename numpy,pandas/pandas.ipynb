# %%
import pandas as pd
weather_data = [("1/1/2024",32,6,"Rain"),
                ("2/11/2024",35,7,"Sunny")]

df = pd.DataFrame(weather_data,columns = ["date","temperature","wind","climate"])
print(df)
# Out:
#         date  temperature  wind climate
# 0   1/1/2024           32     6    Rain
# 1  2/11/2024           35     7   Sunny

# %%
df = pd.read_csv("auto-mpg.csv")
df.head(2) # toget the preview

# df.tail(2)  # to get the last values
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320

# %%
df.shape  # to get the number of rows and the columns
# Out:
# (398, 9)

# %%
df.columns
print(df.columns.tolist)
# Out:
# <bound method IndexOpsMixin.tolist of Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')>

# %%
df["weight"]
# Out:
# 0      3504
# 1      3693
# 2      3436
# 3      3433
# 4      3449
#        ...
# 393    2790
# 394    2130
# 395    2295
# 396    2625
# 397    2720
# Name: weight, Length: 398, dtype: int64

# %%
df[["mpg","weight"]]
# Out:
#       mpg  weight
# 0    18.0    3504
# 1    15.0    3693
# 2    18.0    3436
# 3    16.0    3433
# 4    17.0    3449
# ..    ...     ...
# 393  27.0    2790
# 394  44.0    2130
# 395  32.0    2295
# 396  28.0    2625
# 397  31.0    2720
#
# [398 rows x 2 columns]

# %%
print(df[["mpg","weight"][0]])
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.isna()  # to check if there any missing values
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
print(df["mpg"].min())
print(df["mpg"].max())
print(df["mpg"].mean())
print(df["mpg"].std())
print(df["mpg"].var())
# Out:
# 9.0
# 46.6
# 23.514572864321607
# 7.815984312565782
# 61.089610774274405

# %%
print(df["weight"].min())
# Out:
# 1613

# %%
df[df["weight"] == 1613]
df[df["weight"] == df["weight"].min()]["car name"]
df[df["mpg"] == df["mpg"].max()]["car name"]
# Out:
# 322    mazda glc
# Name: car name, dtype: object

# %%
df[df["mpg"]>40]["car name"]
# Out:
# 244    volkswagen rabbit custom diesel
# 309                          vw rabbit
# 322                          mazda glc
# 324                         datsun 210
# 325               vw rabbit c (diesel)
# 326                 vw dasher (diesel)
# 329                honda civic 1500 gl
# 330               renault lecar deluxe
# 394                          vw pickup
# Name: car name, dtype: object

# %%
df[(df["mpg"] < 40) &  (df["mpg"] > 30)][["car name","mpg"]]
# Out:
#                               car name   mpg
# 53                 toyota corolla 1200  31.0
# 54                         datsun 1200  35.0
# 129                        datsun b210  31.0
# 131                toyota corolla 1200  32.0
# 144                      toyota corona  31.0
# ..                                 ...   ...
# 387  oldsmobile cutlass ciera (diesel)  38.0
# 390                   toyota celica gt  32.0
# 391                  dodge charger 2.2  36.0
# 395                      dodge rampage  32.0
# 397                         chevy s-10  31.0
#
# [76 rows x 2 columns]

# %%
new_df = df[["car name","weight"]]
new_df.to_csv("new_df.csv")
new_df.to_excel("output.xlsx",sheet_name="sheet1")

# %%
a = df["weight_mpg"] = df["weight"] * df["mpg"]
print(a)
# Out:
# 0      63072.0
# 1      55395.0
# 2      61848.0
# 3      54928.0
# 4      58633.0
#         ...
# 393    75330.0
# 394    93720.0
# 395    73440.0
# 396    73500.0
# 397    84320.0
# Length: 398, dtype: float64

# %%
df.sample(n = 10)  # to get a 10 sample data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 386  25.0          6         181.0        110    2945          16.4
# 307  26.8          6         173.0        115    2700          12.9
# 117  29.0          4          68.0         49    1867          19.5
# 28    9.0          8         304.0        193    4732          18.5
# 265  17.5          8         318.0        140    4080          13.7
# 186  27.0          4         101.0         83    2202          15.3
# 27   11.0          8         318.0        210    4382          13.5
# 209  19.0          4         120.0         88    3270          21.9
# 98   16.0          6         250.0        100    3278          18.0
# 6    14.0          8         454.0        220    4354           9.0
#
#      model year  origin                   car name  weight_mpg
# 386          82       1      buick century limited     73625.0
# 307          79       1  oldsmobile omega brougham     72360.0
# ...

# %%
df.sample(frac = 0.2)  # to get the 20 percent of randon data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 225  17.5          6         250.0        110    3520          16.4
# 222  17.0          8         260.0        110    4060          19.0
# 316  19.1          6         225.0         90    3381          18.7
# 268  27.2          4         119.0         97    2300          14.7
# 250  19.4          8         318.0        140    3735          13.2
# ..    ...        ...           ...        ...     ...           ...
# 59   23.0          4          97.0         54    2254          23.5
# 253  20.5          6         200.0         95    3155          18.2
# 384  32.0          4          91.0         67    1965          15.7
# 393  27.0          4         140.0         86    2790          15.6
# 311  32.1          4          98.0         70    2120          15.5
#
#      model year  origin                    car name  weight_mpg
# 225          77       1          chevrolet concours     61600.0
# ...

# %%
g = df.groupby("model year")

# %%
g

# %%
g.max()
# Out:
#              mpg  cylinders  displacement horsepower  weight  acceleration  \
# model year
# 70          27.0          8         455.0         97    4732          20.5
# 71          35.0          8         400.0          ?    5140          20.5
# 72          28.0          8         429.0         97    4633          23.5
# 73          29.0          8         455.0         95    4997          21.0
# 74          32.0          8         350.0          ?    4699          21.0
# 75          33.0          8         400.0         98    4668          21.0
# 76          33.0          8         351.0         95    4380          22.2
# 77          36.0          8         400.0         98    4335          19.0
# 78          43.1          8         318.0         97    4080          21.5
# 79          37.3          8         360.0         90    4360          24.8
# 80          46.6          6         225.0          ?    3381          23.7
# ...

# %%
# concat and merge functions  by using on
# loc and iloc 
# value_counts using unique



df = pd.read_csv("auto-mpg.csv")
df["cylinders"].unique()
df["cylinders"].value_counts()
# Out:
# cylinders
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: count, dtype: int64

# %%
df.values  # this will convert to numpy array
# Out:
# array([[18.0, 8, 307.0, ..., 70, 1, 'chevrolet chevelle malibu'],
#        [15.0, 8, 350.0, ..., 70, 1, 'buick skylark 320'],
#        [18.0, 8, 318.0, ..., 70, 1, 'plymouth satellite'],
#        ...,
#        [32.0, 4, 135.0, ..., 82, 1, 'dodge rampage'],
#        [28.0, 4, 120.0, ..., 82, 1, 'ford ranger'],
#        [31.0, 4, 119.0, ..., 82, 1, 'chevy s-10']],
#       shape=(398, 9), dtype=object)

# %%
car_new =  df.drop(["origin","car name"],axis = 1)  # if we give implace = True we can change the og dataset
car_new.head(2)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70

# %%
# panda series
city1 = pd.Series([12,6,-4,19],index = ["day1","day2","day2","day3"])
city1
# Out:
# day1    12
# day2     6
# day2    -4
# day3    19
# dtype: int64

# %%
print(city1[~city1>2])  # to get the negation
# Out:
# day2   -4
# dtype: int64

# %%
import numpy as np
num_df = df.select_dtypes(include=np.number)   # to get the columns with numbers
df.select_dtypes(include=np.object_).head(2) # to get the numbers wth string
# Out:
#   horsepower                   car name
# 0        130  chevrolet chevelle malibu
# 1        165          buick skylark 320

# %%
num_df.corr()
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.775396     -0.804203 -0.831741      0.420289
# cylinders    -0.775396   1.000000      0.950721  0.896017     -0.505419
# displacement -0.804203   0.950721      1.000000  0.932824     -0.543684
# weight       -0.831741   0.896017      0.932824  1.000000     -0.417457
# acceleration  0.420289  -0.505419     -0.543684 -0.417457      1.000000
# model year    0.579267  -0.348746     -0.370164 -0.306564      0.288137
# origin        0.563450  -0.562543     -0.609409 -0.581024      0.205873
#
#               model year    origin
# mpg             0.579267  0.563450
# cylinders      -0.348746 -0.562543
# displacement   -0.370164 -0.609409
# weight         -0.306564 -0.581024
# acceleration    0.288137  0.205873
# model year      1.000000  0.180662
# origin          0.180662  1.000000

# %%
import seaborn as sns
sns.heatmap(num_df.corr(),annot = True)
# Out:
# <Axes: >
